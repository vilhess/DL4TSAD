# %%
import pandas as pd

# %%
results = pd.read_json("results/simu_aucs.json")
results_std = pd.read_json("results/simu_aucs_std.json")

# %%
results_str = results.astype(float).round(3).astype(str) + " ± " + results_std.astype(float).round(3).astype(str)
results_str
# Out:
#                    nyc_taxi ec2_request_latency_system_failure           swat  \
# patchtrad     0.889 ± 0.035                      0.997 ± 0.002  0.837 ± 0.007
# patchtst      0.747 ± 0.046                        0.999 ± 0.0  0.845 ± 0.006
# patchad       0.975 ± 0.004                        0.998 ± 0.0    0.822 ± 0.0
# jepatchtrad   0.821 ± 0.065                        0.995 ± 0.0  0.815 ± 0.001
# aelstm        0.681 ± 0.079                        0.999 ± 0.0   0.84 ± 0.002
# doc           0.711 ± 0.017                      0.755 ± 0.088  0.504 ± 0.106
# patchtst_rev  0.678 ± 0.041                        0.999 ± 0.0  0.235 ± 0.003
# usad           0.72 ± 0.042                        0.977 ± 0.0    0.504 ± 0.3
# lstm          0.577 ± 0.049                        0.999 ± 0.0  0.839 ± 0.002
# lstm_rev      0.629 ± 0.034                        0.998 ± 0.0  0.238 ± 0.001
# tranad        0.613 ± 0.042                      0.971 ± 0.055  0.813 ± 0.003
# ...
